# %% [markdown]
# # Traveling salesman problem

# %%
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# Создадим изначальную карту.

# %%
letters = [f'{chr(i)}' for i in range(65, 65 + 26)] + [f'{chr(i)}*' for i in range(65, 65 + 26)]

# %%
class City:
    def __init__(self, coord, number):
        self.x = coord[0]
        self.y = coord[1]
        self.name = letters[number]
        
    def distance(self, city):
        return np.sqrt((self.x - city.x) ** 2 + (self.y - city.y) ** 2)
    
    def __repr__(self):
        return f'{self.name}: ({str(self.x)}; {self.y})'

# %%
def map_city(cities_num, cities_range):
    return [City(np.random.randint(1, cities_range, size=2), j) for j in range(cities_num)]

# %%
np.random.seed(13)
not_closed_road = map_city(len(letters), 2000)

# %%
closed_road = not_closed_road + [not_closed_road[0]]

# %%
def total_distance(path, cities_lst): # тождественно нашей целевой функции
    dist_lst = []
    for j in range(len(path) - 1):
        dist_lst.append(cities_lst[j].distance(cities_lst[j + 1]))
    dist_lst.append(cities_lst[j + 1].distance(cities_lst[0]))
    return sum(dist_lst)

# %%
path = [city.name for city in closed_road]

# %%
route_dist = total_distance(path=path, cities_lst=closed_road)

# %%
fig = plt.figure(figsize=(10,10))

# Удаляем лишние границы
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)  
ax.spines["right"].set_visible(False)
ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left() 

# Корректируем оси абсцисс и ординат
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14) 

plt.title(f'Distance: {int(round(route_dist))} km', fontsize=22)
plt.plot([city.x for city in closed_road],
         [city.y for city in closed_road], alpha=0.65)
plt.scatter([city.x for city in closed_road], 
            [city.y for city in closed_road], s=70, marker='o', alpha=0.4)

for j in range(len(closed_road)):
    plt.text(closed_road[j].x + 20, closed_road[j].y - 10,  closed_road[j].name)
    
plt.axis("equal")
sns.set_style("white")

# %%
fig.savefig("TSP1.png", bbox_inches='tight', dpi=600)

# %% [markdown]
# Реализуем генетический алгоритм.

# %%
class Individual:
    def __init__(self, cities_lst, id_of_individual):
        self.map = random.sample(cities_lst[:-1], len(cities_lst[:-1]))
        self.path = [city.name for city in self.map]
        self.id_of_individual = id_of_individual
        self.dist = None
        self.fitness = None
        
    def __repr__(self):
        return f'Individual {self.id_of_individual}: Distance = {int(round(self.dist))} km'

# %%
class GeneticAlgorithm:
    def __init__(self, ell, k, mutation_rate, inital_map, max_iter, make_gif=False):
        """
        PARAMETERS:
        ell --- количество особей в поколении
        k --- количество особей для размножения
        mutation_rate --- коэффициент мутации
        max_iter --- максимальное количество эволюций поколения (новых поколений)
        """
        self.ell = ell
        self.k = k
        self.mutation_rate = mutation_rate
        self.inital_map = inital_map
        self.max_iter = max_iter
        
        self.best_individuals = None # k наиболее приспособленных особей
        self.fittest_indivdual = None # самая приспособленная особь
        self.population = None
        self.best_target_value_history = []
        
    def search_best_path(self):
        # создаем первое поколение
        self.population = self.create_population()
    
        # проходим этапы эволюции
        for i in tqdm(range(self.max_iter)):
            # оцениваем приспособленность наших особей
            self.evaluate_population()
            # отбираем k наиболее наиболее приспособленных особей
            self.selection()
            self.best_target_value_history.append(self.fittest_indivdual.dist)
            
            # формируем новые поколения
            # скрещиваем особи
            for idx in range(self.k, self.ell):
                # случайно выбираем одну из наилучших особей
                select_fitted_individual = np.random.choice(self.best_individuals)
                # создаем потомка и заменяем им старую особь
                offspring = self.crossover(select_fitted_individual,
                                           self.population[idx])
                self.population[idx].map = offspring
            
            # мутируем все особи, кроме самой приспособленной
            for individual in self.population[1:]:
                self.mutate(individual)
            
            if make_gif:
                make_plot(self.fittest_indivdual, i)
            
        return self.fittest_indivdual

    def create_population(self):
        return [Individual(self.inital_map, i + 1) for i in range(self.ell)]
    
    def evaluate_population(self):
        F = []
        
        for individual in self.population:
            individual.dist = total_distance(individual.path + [individual.path[0]],
                                             individual.map + [individual.map[0]])
            F.append(individual.dist)
        
        for individual in self.population:
            individual.fitness = self.normalize(individual.dist,
                                                min(F), max(F))
            
    def normalize(self, z, F_best, F_worst):
        """
        INPUT:
        z --- масштабируемое значение
        F_best --- лучшее значение целевой функции
        F_worst --- худшее значение целевой функции
        """
        return (z - F_worst) / (F_best - F_worst)
    
    def selection(self):
        """
        Оператор отбора
        """
        self.population = sorted(self.population,
                                 key=lambda individual: individual.fitness, reverse=True)
        self.best_individuals = self.population[:self.k]
        self.fittest_indivdual = self.population[0]
    
    def crossover(self, parent_fitted, parent_random):
        """
        Оператор скрещивания
        
        INPUT:
        parent_fitted --- одна из самых приспособленных особей
        parent_random --- случайная особь
        """
        genes_1 = int(np.random.uniform(0, 1) * len(parent_fitted.path))
        genes_2 = int(np.random.uniform(0, 1) * len(parent_fitted.path))
        
        start = min(genes_1, genes_2)
        end = max(genes_1, genes_2)
        
        if (end - start > self.ell / 2) and (np.random.uniform(0, 1) < parent_fitted.fitness):
            offspring_1 = parent_fitted.map[start:end]
            offspring_2 = [city for city in parent_random.map if city not in offspring_1]
        else:
            offspring_1 = parent_random.map[start:end]
            offspring_2 = [city for city in parent_fitted.map if city not in offspring_1]
    
        return offspring_1 + offspring_2
    
    def mutate(self, individual):
        """
        Оператор мутации
    
        INPUT:
        individual --- особь, подвергающаяся мутации
        """
        for j in range(len(individual.path)):
            if np.random.uniform(0, 1) < self.mutation_rate:
                num = np.random.randint(len(individual.path))
                individual.map[j], individual.map[num] = individual.map[num], individual.map[j]

# %% [markdown]
# Инициализируем.

# %%
a = GeneticAlgorithm(ell=1500, k=150, mutation_rate=0.001, inital_map=closed_road, max_iter=1200)

# %%
np.random.seed(1323)
a.search_best_path()
# Out:
# 100%|██████████| 1200/1200 [18:49<00:00,  1.06it/s]
# Individual 1150: Distance = 11249 km

# %% [markdown]
# Решение TSP:

# %%
ans = a.fittest_indivdual.map + [a.fittest_indivdual.map[0]]

fig = plt.figure(figsize=(10,10))

# Удаляем лишние границы
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)  
ax.spines["right"].set_visible(False)
ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left() 

# Корректируем оси абсцисс и ординат
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14) 

plt.title(f'Distance: {int(round(a.fittest_indivdual.dist))} km', fontsize=22)
plt.plot([city.x for city in ans],
         [city.y for city in ans], alpha=0.65)
plt.scatter([city.x for city in ans], 
            [city.y for city in ans], s=70, marker='o', alpha=0.4)

for j in range(len(a.fittest_indivdual.map)):
    plt.text(a.fittest_indivdual.map[j].x + 20, a.fittest_indivdual.map[j].y - 10, a.fittest_indivdual.map[j].name)

plt.axis("equal")
sns.set_style("white")

# %%
fig.savefig("TSP2.png", bbox_inches='tight', dpi=600)

# %%
fig = plt.figure(figsize=(10, 8))

# Удаляем лишние границы
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)  
ax.spines["right"].set_visible(False)
ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left() 

# Корректируем оси абсцисс и ординат
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14) 

plt.xlabel("t", fontsize=20, labelpad=10)  
plt.title("Изменение целевой функции", fontsize=24, pad=10) 
plt.plot(a.best_target_value_history)

fig.tight_layout()

# %%
fig.savefig("TSP3.png", bbox_inches='tight', dpi=600)

# %% [markdown]
# # Гифка

# %%
import os
import glob
import imageio
images = 'images/'

# %%
def create_animated_gif(files, animated_gif_name, pause=0):
    if pause != 0:
        # Load the gifs up several times in the array, to slow down the animation
        frames = []
        for file in files:
            count = 0
            while count < pause:
                frames.append(file)
                count+=1
        print("Total number of frames in the animation:", len(frames))
        files = frames
    images = [imageio.imread(file) for file in files]
    imageio.mimsave(animated_gif_name, images, duration = 0.005)

# %%
# удаляет из папки вообще все картинки
for f in glob.glob("images/*.png"):
    os.remove(f)

# %%
def make_plot(indiv, i):
    ans = indiv.map + [indiv.map[0]]
    
    fig = plt.figure(figsize=(10,10))

    # Удаляем лишние границы
    ax = plt.subplot(111)  
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.get_xaxis().tick_bottom()  
    ax.get_yaxis().tick_left() 

    # Корректируем оси абсцисс и ординат
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14) 

    plt.title(f'Distance: {int(round(indiv.dist))} km', fontsize=22)
    plt.plot([city.x for city in ans],
             [city.y for city in ans], alpha=0.65)
    plt.scatter([city.x for city in ans], 
                [city.y for city in ans], s=70, marker='o', alpha=0.4)

    for j in range(len(indiv.map)):
        plt.text(indiv.map[j].x + 20, indiv.map[j].y - 10, indiv.map[j].name)

    plt.axis("equal")
    
    fig.savefig('images/{}.png'.format(i+1), dpi=300)

# %%
class GeneticAlgorithm:
    def __init__(self, ell, k, mutation_rate, inital_map, max_iter):
        """
        PARAMETERS:
        ell --- количество особей в поколении
        k --- количество особей для размножения
        mutation_rate --- коэффициент мутации
        max_iter --- максимальное количество эволюций поколения (новых поколений)
        """
        self.ell = ell
        self.k = k
        self.mutation_rate = mutation_rate
        self.inital_map = inital_map
        self.max_iter = max_iter
        
        self.best_individuals = None # k наиболее приспособленных особей
        self.fittest_indivdual = None # самая приспособленная особь
        self.population = None
        self.best_target_value_history = []
        
    def search_best_path(self):
        # создаем первое поколение
        self.population = self.create_population()
    
        # проходим этапы эволюции
        for i in tqdm(range(self.max_iter)):
            # оцениваем приспособленность наших особей
            self.evaluate_population()
            # отбираем k наиболее наиболее приспособленных особей
            self.selection()
            self.best_target_value_history.append(self.fittest_indivdual.dist)
            
            # формируем новые поколения
            # скрещиваем особи
            for idx in range(self.k, self.ell):
                # случайно выбираем одну из наилучших особей
                select_fitted_individual = np.random.choice(self.best_individuals)
                # создаем потомка и заменяем им старую особь
                offspring = self.crossover(select_fitted_individual,
                                           self.population[idx])
                self.population[idx].map = offspring
            
            # мутируем все особи, кроме самой приспособленной
            for individual in self.population[1:]:
                self.mutate(individual)
    
            make_plot(self.fittest_indivdual, i)
            
        return self.fittest_indivdual

    def create_population(self):
        return [Individual(self.inital_map, i + 1) for i in range(self.ell)]
    
    def evaluate_population(self):
        F = []
        
        for individual in self.population:
            individual.dist = total_distance(individual.path + [individual.path[0]],
                                             individual.map + [individual.map[0]])
            F.append(individual.dist)
        
        for individual in self.population:
            individual.fitness = self.normalize(individual.dist,
                                                min(F), max(F))
            
    def normalize(self, z, F_best, F_worst):
        """
        INPUT:
        z --- масштабируемое значение
        F_best --- лучшее значение целевой функции
        F_worst --- худшее значение целевой функции
        """
        return (z - F_worst) / (F_best - F_worst)
    
    def selection(self):
        """
        Оператор отбора
        """
        self.population = sorted(self.population,
                                 key=lambda individual: individual.fitness, reverse=True)
        self.best_individuals = self.population[:self.k]
        self.fittest_indivdual = self.population[0]
    
    def crossover(self, parent_fitted, parent_random):
        """
        Оператор скрещивания
        
        INPUT:
        parent_fitted --- одна из самых приспособленных особей
        parent_random --- случайная особь
        """
        genes_1 = int(np.random.uniform(0, 1) * len(parent_fitted.path))
        genes_2 = int(np.random.uniform(0, 1) * len(parent_fitted.path))
        
        start = min(genes_1, genes_2)
        end = max(genes_1, genes_2)
        
        if (end - start > self.ell / 2) and (np.random.uniform(0, 1) < parent_fitted.fitness):
            offspring_1 = parent_fitted.map[start:end]
            offspring_2 = [city for city in parent_random.map if city not in offspring_1]
        else:
            offspring_1 = parent_random.map[start:end]
            offspring_2 = [city for city in parent_fitted.map if city not in offspring_1]
    
        return offspring_1 + offspring_2
    
    def mutate(self, individual):
        """
        Оператор мутации
    
        INPUT:
        individual --- особь, подвергающаяся мутации
        """
        for j in range(len(individual.path)):
            if np.random.uniform(0, 1) < self.mutation_rate:
                num = np.random.randint(len(individual.path))
                individual.map[j], individual.map[num] = individual.map[num], individual.map[j]

# %%
a = GeneticAlgorithm(ell=1500, k=150, mutation_rate=0.001, inital_map=closed_road, max_iter=1200)

# %%
np.random.seed(1323)
a.search_best_path()
# Out:
#   2%|▏         | 20/1200 [00:27<26:05,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 21/1200 [00:28<26:06,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 22/1200 [00:30<26:06,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 23/1200 [00:31<26:29,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 24/1200 [00:32<26:33,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 25/1200 [00:34<26:24,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 26/1200 [00:35<26:36,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 27/1200 [00:36<26:40,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 28/1200 [00:38<26:26,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▏         | 29/1200 [00:39<26:15,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   2%|▎         | 30/1200 [00:40<26:04,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 31/1200 [00:42<25:59,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 32/1200 [00:43<25:54,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 33/1200 [00:44<25:46,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 34/1200 [00:46<26:05,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 35/1200 [00:47<26:00,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 36/1200 [00:48<25:58,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 37/1200 [00:50<25:49,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 38/1200 [00:51<26:18,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 39/1200 [00:52<26:03,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 40/1200 [00:54<25:54,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   3%|▎         | 41/1200 [00:55<25:52,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▎         | 42/1200 [00:56<25:49,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▎         | 43/1200 [00:58<25:47,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▎         | 44/1200 [00:59<25:47,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 45/1200 [01:00<25:36,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 46/1200 [01:02<25:29,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 47/1200 [01:03<25:29,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 48/1200 [01:04<25:25,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 49/1200 [01:06<25:36,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 50/1200 [01:07<25:29,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 51/1200 [01:08<25:21,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 52/1200 [01:10<25:39,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 53/1200 [01:11<25:34,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   4%|▍         | 54/1200 [01:13<26:42,  1.40s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▍         | 55/1200 [01:14<27:08,  1.42s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▍         | 56/1200 [01:16<26:53,  1.41s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▍         | 57/1200 [01:17<26:31,  1.39s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▍         | 58/1200 [01:18<26:08,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▍         | 59/1200 [01:20<25:46,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 60/1200 [01:21<25:30,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 61/1200 [01:22<25:24,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 62/1200 [01:24<25:24,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 63/1200 [01:25<25:18,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 64/1200 [01:26<25:14,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   5%|▌         | 65/1200 [01:28<25:18,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 66/1200 [01:29<25:16,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 67/1200 [01:30<25:11,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 68/1200 [01:31<25:06,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 69/1200 [01:33<25:06,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 70/1200 [01:34<26:01,  1.38s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 71/1200 [01:36<25:43,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 72/1200 [01:37<25:49,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 73/1200 [01:38<25:38,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▌         | 74/1200 [01:40<25:52,  1.38s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▋         | 75/1200 [01:41<25:32,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▋         | 76/1200 [01:42<25:16,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▋         | 77/1200 [01:44<25:20,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   6%|▋         | 78/1200 [01:45<25:10,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 79/1200 [01:46<25:07,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 80/1200 [01:48<25:06,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 81/1200 [01:49<25:03,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 82/1200 [01:50<24:56,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 83/1200 [01:52<24:51,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 84/1200 [01:53<24:51,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 85/1200 [01:54<24:45,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 86/1200 [01:56<24:38,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 87/1200 [01:57<24:59,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 88/1200 [01:59<24:44,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   7%|▋         | 89/1200 [02:00<24:35,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 90/1200 [02:01<24:28,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 91/1200 [02:03<26:19,  1.42s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 92/1200 [02:04<25:38,  1.39s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 93/1200 [02:05<25:12,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 94/1200 [02:07<25:00,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 95/1200 [02:08<24:44,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 96/1200 [02:09<24:29,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 97/1200 [02:11<24:19,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 98/1200 [02:12<24:22,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 99/1200 [02:13<24:11,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 100/1200 [02:15<24:06,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 101/1200 [02:16<24:00,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   8%|▊         | 102/1200 [02:17<23:58,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▊         | 103/1200 [02:19<24:26,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▊         | 104/1200 [02:20<24:10,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 105/1200 [02:21<24:02,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 106/1200 [02:23<23:58,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 107/1200 [02:24<23:49,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 108/1200 [02:25<23:51,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 109/1200 [02:26<23:49,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 110/1200 [02:28<24:03,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 111/1200 [02:29<23:53,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 112/1200 [02:30<23:47,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#   9%|▉         | 113/1200 [02:32<23:44,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 114/1200 [02:33<23:38,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 115/1200 [02:34<23:35,  1.30s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 116/1200 [02:36<25:06,  1.39s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 117/1200 [02:37<24:49,  1.38s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 118/1200 [02:39<24:26,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|▉         | 119/1200 [02:40<24:08,  1.34s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 120/1200 [02:41<23:55,  1.33s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 121/1200 [02:42<23:44,  1.32s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 122/1200 [02:44<23:35,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 123/1200 [02:45<23:32,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 124/1200 [02:46<23:31,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 125/1200 [02:48<23:25,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  10%|█         | 126/1200 [02:49<23:22,  1.31s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  11%|█         | 127/1200 [02:50<23:17,  1.30s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# ...
#   after removing the cwd from sys.path.
#  57%|█████▋    | 679/1200 [16:26<11:49,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 680/1200 [16:27<11:52,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 681/1200 [16:28<11:53,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 682/1200 [16:30<11:47,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 683/1200 [16:31<11:49,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 684/1200 [16:33<11:58,  1.39s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 685/1200 [16:34<12:07,  1.41s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 686/1200 [16:36<12:06,  1.41s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 687/1200 [16:37<12:14,  1.43s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 688/1200 [16:38<12:10,  1.43s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▋    | 689/1200 [16:40<12:30,  1.47s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  57%|█████▊    | 690/1200 [16:41<12:17,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 691/1200 [16:43<12:11,  1.44s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 692/1200 [16:44<12:14,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 693/1200 [16:46<12:09,  1.44s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 694/1200 [16:47<12:05,  1.43s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 695/1200 [16:49<12:02,  1.43s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 696/1200 [16:50<12:39,  1.51s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 697/1200 [16:52<12:27,  1.49s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 698/1200 [16:53<12:09,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 699/1200 [16:54<12:08,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 700/1200 [16:56<12:02,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 701/1200 [16:57<12:07,  1.46s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  58%|█████▊    | 702/1200 [16:59<12:03,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▊    | 703/1200 [17:00<11:59,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▊    | 704/1200 [17:02<11:58,  1.45s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 705/1200 [17:03<12:10,  1.48s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 706/1200 [17:05<11:44,  1.43s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 707/1200 [17:06<11:29,  1.40s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 708/1200 [17:07<11:16,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 709/1200 [17:09<11:13,  1.37s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 710/1200 [17:10<11:14,  1.38s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 711/1200 [17:11<11:03,  1.36s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 712/1200 [17:13<10:58,  1.35s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  59%|█████▉    | 713/1200 [17:14<11:56,  1.47s/it]/Users/khaykingleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
#  60%|█████▉    | 714/1200 [17:16<11:40,  1.44s/it]

# %%
pause = 1
animated_gif_name = 'animation_CPT_2.gif'

# %%
image_path = 'images/*.png'
files = glob.glob(image_path)
files = sorted(files, key = lambda w: int(w.split('/')[-1].split('.')[0]))
create_animated_gif(files, animated_gif_name, pause)
# Out:
# Total number of frames in the animation: 522
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-bc69c612ea2d> in <module>
#       2 files = glob.glob(image_path)
#       3 files = sorted(files, key = lambda w: int(w.split('/')[-1].split('.')[0]))
# ----> 4 create_animated_gif(files, animated_gif_name, pause)
#
# <ipython-input-43-f9d542133d62> in create_animated_gif(files, animated_gif_name, pause)
#      10         print("Total number of frames in the animation:", len(frames))
#      11         files = frames
# ---> 12     images = [imageio.imread(file) for file in files]
#      13     imageio.mimsave(animated_gif_name, images, duration = 0.005)
#
# <ipython-input-43-f9d542133d62> in <listcomp>(.0)
#      10         print("Total number of frames in the animation:", len(frames))
#      11         files = frames
# ---> 12     images = [imageio.imread(file) for file in files]
#      13     imageio.mimsave(animated_gif_name, images, duration = 0.005)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     262
#     263     # Get reader and read first
# --> 264     reader = read(uri, format, "i", **kwargs)
#     265     with reader:
#     266         return reader.get_data(0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     184
#     185     # Return its reader object
# --> 186     return format.get_reader(request)
#     187
#     188
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/format.py in get_reader(self, request)
#     162                 "Format %s cannot read in mode %r" % (self.name, select_mode)
#     163             )
# --> 164         return self.Reader(self, request)
#     165
#     166     def get_writer(self, request):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/format.py in __init__(self, format, request)
#     212             self._request = request
#     213             # Open the reader/writer
# --> 214             self._open(**self.request.kwargs.copy())
#     215
#     216         @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/plugins/pillow.py in _open(self, pilmode, as_gray, ignoregamma)
#     298     class Reader(PillowFormat.Reader):
#     299         def _open(self, pilmode=None, as_gray=False, ignoregamma=True):
# --> 300             return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#     301
#     302         def _get_data(self, index):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/plugins/pillow.py in _open(self, pilmode, as_gray)
#     135             if self._im.palette and self._im.palette.dirty:
#     136                 self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 137             pil_try_read(self._im)
#     138             # Store args
#     139             self._kwargs = dict(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/plugins/pillow.py in pil_try_read(im)
#     669     try:
#     670         # this will raise an IOError if the file is not readable
# --> 671         im.getdata()[0]
#     672     except IOError as e:
#     673         site = "http://pillow.readthedocs.io/en/latest/installation.html"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in getdata(self, band)
#    1247         """
#    1248
# -> 1249         self.load()
#    1250         if band is not None:
#    1251             return self.im.getband(band)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:
