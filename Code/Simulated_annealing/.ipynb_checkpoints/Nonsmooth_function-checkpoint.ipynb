# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

# %%
def F(x):
    return x ** 2 * (1 + abs(np.sin(30 * x)))

# %%
x_space = np.linspace(-2, 2, 1000)

# %%
fig = plt.figure(figsize=(12, 8))

# Удаляем лишние границы
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)  
ax.spines["right"].set_visible(False)
ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left() 

# Корректируем оси абсцисс и ординат
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14) 

plt.xlabel("$x$", fontsize=14)  
plt.ylabel("$f(x)$", fontsize=14)

plt.plot(x_space, F(x_space))

# %%
fig.savefig("func_min.png", bbox_inches='tight', dpi=600)

# %%
def SA(space, T):
    x_hat = np.random.choice(space)
    T_0 = T
    k = 1
    while F(x_hat)!= 0:
        x_tilda = np.random.normal(x_hat, T)
        delta = F(x_tilda) - F(x_hat)
        prob = np.exp(- delta / T)
        
        if (delta < 0) or (prob >= np.random.random()):
            x_hat = x_tilda
        
        T = T_0/ np.log(1 + k) 
        
    return x_hat

# %%
def SA_adj(func, space, T):
    x_hat = np.random.chocie()
    history = list()

# %%
np.random.normal()
# Out:
# 0.5909066363480504

# %%
SA(x_space, 0.5)

# %%
T = 10

# %%
def F(Q, N): # Q означает расположение ферзей
    cnt = 0
    for i in range(N):
        for j in range(i + 1, N):
            if abs(Q[i, 0] - Q[j, 0]) == abs(Q[i, 1] - Q[j, 1]): 
                cnt += 1
    return cnt * 2 # учитываем взаимные атаки

# %%
def G(Q, N):
    pos = Q.copy()
    while True:
        i = np.random.randint(0, N - 1)
        j = np.random.randint(0, N - 1)
    
        if i != j:
            break
            
    pos[i, 1], pos[j, 1] = pos[j, 1], pos[i, 1]
    return pos # получаем новое расположение ферзей

# %%
def SA(T, schedule):
    x_hat = np.random.uniform(-2, 2)
    while x_hat != 0:
        x_tilda = G(x_hat)
        delta = F(x_tilda, N) - F(x_hat, N)
        prob = np.exp(- delta / T)
        
        if (delta < 0) or (prob >= np.random.random()):
            x_hat = x_tilda
        
        T *= schedule 
    
    return x_hat

# %%
# Out:
# 1.9946474111627377
